# %% [markdown]
# # Data Cleaning
# ---
#
# ### Table of Contents <a class="anchor" id="toc"></a>
#
# * [Overview](#overview)
# * [Importing Libraries](#importinglibraries)
# * [Creating Custom Functions](#customfunctions)
# * [Importing Raw Datasets](#importcsv)
# * [Checking 'Minimum Salary' and 'Maximum Salary'](#checkminmaxsalary)
# * [Standardizing 'Job Title'](#standardizejobtitle)
# * [Standardizing 'Employment Type'](#standardizeemploymenttype)
# * [Standardizing 'Position Level'](#standardizepositionlevel)
# * [Converting datetime variables](#convertdatetime)
# * [Exporting Dataset for EDA](#exportcsv)

# %% [markdown]
# ## Overview<a class="anchor" id="overview"></a>
# ---
# [Back to top!](#toc)
#
# This notebook will be concatenating and cleaning up the scraped datasets from the previous notebook.
# * Feature engineering `salary_average` from `minimum_salary` and `maximum_salary`
# * Removing outlier points from `salary_average`
# * Standardizing `job_title` to categorical variable
# * Standardizing `employment_type` to categorical variable
# * Retaining only the `employment_type` that are full-time job listings
# * Standardizing `position_level` to categorical variable
# * Converting `new_posting_date`, `original_posting_date` and `closing_date` to datetime variables and feature engineering the no. of days to closing date for application
# * Dropping unnecessary columns such as `job_id`, `ext_job_id`, `ssoc_code`, `last_updated`, `salary_type`, `api_link`, `job_url`
#
# #### Data Dictionary
#
# | |Feature|Type|Description|
# |---|---|---|---|
# |**0**|job_id|object|Identification no. for job posting|
# |**1**|ext_job_id|object|Identification no. for job posting|
# |**2**|job_title|object|Job Title|
# |**3**|job_description|object|Job Description|
# |**4**|minimum_years_experience|int|Minimum no. of years experience required|
# |**5**|ssoc_code|int|Code no. for job posting|
# |**6**|categories|object|Job Category e.g. Information Technology, Banking & Finance|
# |**7**|employment_types|object|Type of employment e.g. full-time, part-time|
# |**8**|position_levels|object|Position Level e.g. entry level, executive, management|
# |**9**|new_posting_date|object|New posting date|
# |**10**|original_posting_date|object|Original posting date|
# |**11**|closing_date|object|Closing date for application|
# |**12**|last_updated|object|Last updated posting date|
# |**13**|skills|object|Skills required for job listing|
# |**14**|organisation|object|Company Name|
# |**15**|salary_minimum|int|Minimum salary offered|
# |**16**|salary_maximum|int|Maximum salary offered|
# |**17**|salary_type|object|Type of salary e.g. monthly, yearly|
# |**18**|api_link|object|URL|
# |**19**|job_url|object|URL|

# %% [markdown]
# ## Importing Libraries <a class="anchor" id="importinglibraries"></a>
# ---
# [Back to top!](#toc)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')

from sklearn.feature_extraction.text import CountVectorizer

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Custom Functions <a class="anchor" id="customfunctions"></a>
# ---
# [Back to top!](#toc)

# %%
def get_top_words(df, top_num):
    '''Input: dataframe to get word occurrence, top number of occurrence
       Output: dataframe with only top occurring words'''
    df = pd.DataFrame(df.sum().sort_values(ascending=False).head(top_num))
    df = df.reset_index()
    df.columns = ['words', 'counts']
    return df

# %% [markdown]
# ## Importing Raw Datasets <a class="anchor" id="importcsv"></a>
# ---
# [Back to top!](#toc)

# %%
df_data = pd.read_csv('../data/mycareersfuturesg_results_data_210511.csv')
df_dscientist = pd.read_csv('../data/mycareersfuturesg_results_data_scientist_210511.csv')
df_danalyst = pd.read_csv('../data/mycareersfuturesg_results_data_analyst_210511.csv')
df_dengineer = pd.read_csv('../data/mycareersfuturesg_results_data_engineer_210511.csv')
df_bi = pd.read_csv('../data/mycareersfuturesg_results_business_analyst_210511.csv')
df_ml = pd.read_csv('../data/mycareersfuturesg_results_machine_learning_210511.csv')
df_py = pd.read_csv('../data/mycareersfuturesg_results_python_210511.csv')

# %%
print("from 'mycareersfuture.gov.sg'")
print('-----------------------------')
print(f"search for 'data': {df_data.shape}")
print(f"search for 'data scientist': {df_dscientist.shape}")
print(f"search for 'data analyst': {df_danalyst.shape}")
print(f"search for 'data engineer': {df_dengineer.shape}")
print(f"search for 'business analyst': {df_bi.shape}")
print(f"search for 'machine learning': {df_ml.shape}")
print(f"search for 'python': {df_py.shape}")
# Out:
# from 'mycareersfuture.gov.sg'
# -----------------------------
# search for 'data': (15102, 20)
# search for 'data scientist': (200, 20)
# search for 'data analyst': (291, 20)
# search for 'data engineer': (284, 20)
# search for 'business analyst': (890, 20)
# search for 'machine learning': (933, 20)
# search for 'python': (2677, 20)

# %%
# concatenating dataframes
df = pd.concat([df_data, df_dscientist, df_danalyst, df_dengineer, df_bi, df_ml, df_py], axis=0)
df.shape
# Out:
# (20377, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20377 entries, 0 to 2676
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   job_id                    20377 non-null  object
#  1   ext_job_id                20377 non-null  object
#  2   job_title                 20377 non-null  object
#  3   job_description           20377 non-null  object
#  4   minimum_years_experience  20377 non-null  int64
#  5   ssoc_code                 20377 non-null  int64
#  6   categories                20377 non-null  object
#  7   employment_types          20377 non-null  object
#  8   position_levels           19776 non-null  object
#  9   new_posting_date          20377 non-null  object
#  10  original_posting_date     20377 non-null  object
#  11  closing_date              20377 non-null  object
#  12  last_updated              20377 non-null  object
#  13  skills                    20377 non-null  object
#  14  organisation              20377 non-null  object
#  15  salary_minimum            20377 non-null  int64
#  16  salary_maximum            20377 non-null  int64
#  17  salary_type               20377 non-null  object
#  18  api_link                  20377 non-null  object
#  19  job_url                   20377 non-null  object
# dtypes: int64(4), object(16)
# memory usage: 3.3+ MB

# %%
# dropping unnecessary columns
df.drop(columns=['job_id', 'ext_job_id', 'ssoc_code', 'api_link', 'job_url'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20377 entries, 0 to 2676
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   job_title                 20377 non-null  object
#  1   job_description           20377 non-null  object
#  2   minimum_years_experience  20377 non-null  int64
#  3   categories                20377 non-null  object
#  4   employment_types          20377 non-null  object
#  5   position_levels           19776 non-null  object
#  6   new_posting_date          20377 non-null  object
#  7   original_posting_date     20377 non-null  object
#  8   closing_date              20377 non-null  object
#  9   last_updated              20377 non-null  object
#  10  skills                    20377 non-null  object
#  11  organisation              20377 non-null  object
#  12  salary_minimum            20377 non-null  int64
#  13  salary_maximum            20377 non-null  int64
#  14  salary_type               20377 non-null  object
# dtypes: int64(3), object(12)
# memory usage: 2.5+ MB

# %%
# checking for no. of duplicates
df.duplicated().sum()
# Out:
# 3830

# %%
# dropping duplicates
df.drop_duplicates(keep = "first", inplace = True)
df.shape
# Out:
# (16547, 15)

# %% [markdown]
# ## Checking `salary_minimum` and `salary_maximum` <a class="anchor" id="checkminmaxsalary"></a>
# ---
# [Back to top!](#toc)

# %%
# checking indexes without salary input
(df['salary_minimum'] == 0).sum()
(df['salary_maximum'] == 0).sum()
# Out:
# 639

# %%
# dropping indexes without salary input
df = df[df.salary_minimum != 0]
df.shape
# Out:
# (15908, 15)

# %%
# creating new column for average salary
df['salary_average'] = (df['salary_minimum'] + df['salary_maximum'])/2
df.drop(columns=['salary_minimum', 'salary_maximum'], inplace=True)
df.head()
# Out:
#                                            job_title  \
# 0         Senior Derivatives XA Market Data Engineer
# 1  IT - Business Analyst (Data Analytics and Mach...
# 2  Junior Data Analyst (Finance / Python) - up to...
# 3                          Data Analytics Consultant
# 4                         (IT)- Data science analyst
#
#                                      job_description  \
# 0  At ICE we approach every challenge as an oppor...
# 1  [ COLLECTION, USE AND DISCLOSURE OF PERSONAL D...
# 2  We are a top 8 global IT services company with...
# 3  This TMCA* (TeSA Mid-Career Advancement) progr...
# 4  We are a top 8 global IT services company with...
#
#    minimum_years_experience  \
# 0                         5
# 1                         3
# 2                         2
# 3                        15
# 4                         2
#
#                                           categories  \
# 0        Banking and Finance; Information Technology
# 1                             Information Technology
# 2                             Information Technology
# 3  Consulting; Education and Training; Informatio...
# 4                             Information Technology
#
#                     employment_types   position_levels new_posting_date  \
# 0                          Permanent      Professional       2021-04-28
# 1                Contract; Full Time         Executive       2021-04-23
# 2                Contract; Full Time  Junior Executive       2021-04-14
# 3  Full Time; Internship/Traineeship      Professional       2021-04-30
# 4                Contract; Full Time  Senior Executive       2021-04-18
#
#   original_posting_date closing_date              last_updated  \
# 0            2021-03-17   2021-05-28  2021-05-10T16:39:19.000Z
# 1            2021-04-23   2021-05-23  2021-05-10T16:28:53.000Z
# 2            2021-04-14   2021-05-14  2021-05-10T16:34:46.000Z
# 3            2020-12-18   2021-05-30  2021-05-10T16:41:51.000Z
# 4            2021-04-18   2021-05-18  2021-05-10T16:28:23.000Z
#
#                                               skills  \
# 0  Analytics; Communication; Data; Detail Oriente...
# 1  Agile; Agile Methodolgy; Banking; Business Ana...
# 2  Access; Business Process; Data; Data Analysis;...
# 3  Analysis; Business Change Management; Business...
# 4  Business Process; Data; MySQL; MySQL DBA; Orac...
#
#                             organisation salary_type  salary_average
# 0  ICE DATA SERVICES SINGAPORE PTE. LTD.     Monthly         13125.0
# 1           NTT DATA SINGAPORE PTE. LTD.     Monthly          4500.0
# 2           NTT DATA SINGAPORE PTE. LTD.     Monthly          3400.0
# 3    DATA & ANALYTICS CAPITALS PTE. LTD.     Monthly          6000.0
# 4           NTT DATA SINGAPORE PTE. LTD.     Monthly          6000.0

# %%
# checking salary type
df.salary_type.value_counts()

# dropping since all are the same values
df.drop(columns=['salary_type'], inplace=True)

# %% [markdown]
# ## Standardizing `job_title` <a class="anchor" id="standardizejobtitle"></a>
# ---
# [Back to top!](#toc)

# %%
df['job_title'].value_counts()
# Out:
# Business Analyst                                                                                                                                                                       93
# Software Engineer                                                                                                                                                                      69
# Data Engineer                                                                                                                                                                          59
# Admin Assistant                                                                                                                                                                        54
# Product Manager                                                                                                                                                                        51
# Data Analyst                                                                                                                                                                           47
# DevOps Engineer                                                                                                                                                                        45
# Accounts Executive                                                                                                                                                                     40
# Accounts Assistant                                                                                                                                                                     40
# Data Scientist                                                                                                                                                                         34
# Software Developer                                                                                                                                                                     32
# Senior Software Engineer                                                                                                                                                               30
# Administrator                                                                                                                                                                          27
# Accountant                                                                                                                                                                             27
# Full Stack Developer                                                                                                                                                                   27
# Java Developer                                                                                                                                                                         24
# Project Manager                                                                                                                                                                        23
# Network Engineer                                                                                                                                                                       22
# Project Engineer                                                                                                                                                                       21
# Senior Business Analyst                                                                                                                                                                21
# Marketing Executive                                                                                                                                                                    21
# Operations Executive                                                                                                                                                                   20
# Digital Marketing Executive                                                                                                                                                            19
# Marketing Manager                                                                                                                                                                      19
# Business Development Executive                                                                                                                                                         19
# Business Analyst                                                                                                                                                                       19
# Business Development Manager                                                                                                                                                           18
# Solution Architect                                                                                                                                                                     18
# Warehouse Assistant                                                                                                                                                                    17
# Senior Consultant                                                                                                                                                                      17
# Senior Product Manager                                                                                                                                                                 17
# Account Executive                                                                                                                                                                      16
# Software Engineer                                                                                                                                                                      16
# Admin Executive                                                                                                                                                                        15
# Senior Java Developer                                                                                                                                                                  15
# Account Assistant                                                                                                                                                                      15
# Senior Data Engineer                                                                                                                                                                   15
# Research Fellow                                                                                                                                                                        14
# System Engineer                                                                                                                                                                        14
# Sales Executive                                                                                                                                                                        14
# Administrative Assistant                                                                                                                                                               14
# Customer Service Executive                                                                                                                                                             14
# Consultant                                                                                                                                                                             14
# Senior Software Developer                                                                                                                                                              14
# Land Surveyor                                                                                                                                                                          13
# Finance Executive                                                                                                                                                                      12
# Analyst                                                                                                                                                                                12
# IT Executive                                                                                                                                                                           12
# Account Manager                                                                                                                                                                        12
# Admin                                                                                                                                                                                  12
# IT Business Analyst                                                                                                                                                                    12
# Administrative Executive                                                                                                                                                               12
# HR Executive                                                                                                                                                                           12
# Senior Data Scientist                                                                                                                                                                  12
# #SgUnitedJobs Research Engineer/Senior Research Engineer (ARTC)                                                                                                                        11
# Software Tester                                                                                                                                                                        11
# Director                                                                                                                                                                               10
# Research Engineer                                                                                                                                                                      10
# Senior Network Engineer                                                                                                                                                                10
# Customer Service Officer                                                                                                                                                               10
# Devops Engineer                                                                                                                                                                        10
# Desktop Support Engineer                                                                                                                                                               10
# Data Entry Clerk                                                                                                                                                                       10
# Android Developer                                                                                                                                                                      10
# Senior iOS Developer                                                                                                                                                                   10
# Financial Analyst                                                                                                                                                                      10
# Sales Manager                                                                                                                                                                          10
# System Administrator                                                                                                                                                                   10
# Finance Manager                                                                                                                                                                         9
# Personal Assistant                                                                                                                                                                      9
# Marketing Assistant                                                                                                                                                                     9
# QA Engineer                                                                                                                                                                             9
# Front-End Software Engineer                                                                                                                                                             9
# Mechanical Engineer                                                                                                                                                                     9
# Fullstack Software Engineer                                                                                                                                                             9
# Sales Engineer                                                                                                                                                                          9
# Full Stack Engineer                                                                                                                                                                     9
# Digital Marketing Manager                                                                                                                                                               9
# Quantity Surveyor                                                                                                                                                                       9
# Electrical Engineer                                                                                                                                                                     8
# General Manager                                                                                                                                                                         8
# Retail Manager                                                                                                                                                                          8
# Sales Coordinator                                                                                                                                                                       8
# Product Development Engineer                                                                                                                                                            8
# Back-End Software Engineer                                                                                                                                                              8
# Administration Clerk                                                                                                                                                                    8
# Recruitment Consultant                                                                                                                                                                  8
# Engineer                                                                                                                                                                                8
# iOS/Android Software Engineer                                                                                                                                                           8
# Senior Android Developer                                                                                                                                                                8
# Scrum Master                                                                                                                                                                            8
# Enterprise Architect                                                                                                                                                                    8
# Tableau Developer                                                                                                                                                                       8
# Senior DevOps Engineer                                                                                                                                                                  8
# Admin Assistant                                                                                                                                                                         8
# Senior Engineer                                                                                                                                                                         8
# #SgUnitedJobs Scientist (ARTC)                                                                                                                                                          8
# HR Assistant                                                                                                                                                                            7
# Python Developer                                                                                                                                                                        7
# Web Developer                                                                                                                                                                           7
# Solutions Architect                                                                                                                                                                     7
# Backend Engineer                                                                                                                                                                        7
# Senior Product Development Engineer                                                                                                                                                     7
# Database Administrator                                                                                                                                                                  7
# Accounts & Admin Assistant                                                                                                                                                              7
# Customer Success Manager                                                                                                                                                                7
# Personal Assistant                                                                                                                                                                      7
# BIM Modeller                                                                                                                                                                            7
# Admin Coordinator                                                                                                                                                                       7
# Sales Director                                                                                                                                                                          7
# Test Engineer                                                                                                                                                                           7
# iOS Developer                                                                                                                                                                           7
# Operations Manager                                                                                                                                                                      7
# Document Controller                                                                                                                                                                     7
# Site Engineer                                                                                                                                                                           7
# Cyber Security Analyst                                                                                                                                                                  7
# Management Trainee                                                                                                                                                                      7
# Full Stack Developer                                                                                                                                                                    7
# Backend Developer                                                                                                                                                                       7
# Senior Recruitment Consultant                                                                                                                                                           7
# Senior Data Analyst                                                                                                                                                                     6
# #SGUnitedJobs Scientist (Machine Intellection), I2R                                                                                                                                     6
# Manufacturing Technician                                                                                                                                                                6
# Technical Support Engineer                                                                                                                                                              6
# Database Developer                                                                                                                                                                      6
# Software Engineer (Java)                                                                                                                                                                6
# Lead Consultant                                                                                                                                                                         6
# IOS Developer                                                                                                                                                                           6
# Junior Technical Procurement Specialist                                                                                                                                                 6
# Data Engineer                                                                                                                                                                           6
# Sales Administrator                                                                                                                                                                     6
# Automation Engineer                                                                                                                                                                     6
# Game Designer                                                                                                                                                                           6
# Purchasing Coordinator                                                                                                                                                                  6
# Big Data Engineer                                                                                                                                                                       6
# #SgUnitedJobs Research Engineer (ARTC)                                                                                                                                                  6
# Logistics Executive                                                                                                                                                                     6
# Senior Technical Account Manager                                                                                                                                                        6
# Machine Learning Engineer                                                                                                                                                               6
# DevOps Engineer                                                                                                                                                                         6
# Purchasing Assistant                                                                                                                                                                    6
# Senior Project Manager                                                                                                                                                                  6
# Research Assistant                                                                                                                                                                      6
# Warehouse Supervisor                                                                                                                                                                    6
# Senior Product Designer                                                                                                                                                                 6
# Purchaser                                                                                                                                                                               6
# Engineering Manager                                                                                                                                                                     6
# Business Development Consultant                                                                                                                                                         6
# Technical Lead                                                                                                                                                                          6
# System Analyst                                                                                                                                                                          6
# Marketing Specialist                                                                                                                                                                    6
# Human Resource Executive                                                                                                                                                                6
# Process Engineer                                                                                                                                                                        5
# Senior Process Engineer                                                                                                                                                                 5
# Customer Experience Officer                                                                                                                                                             5
# #SGUnitedJobs Business Analyst                                                                                                                                                          5
# Cloud Engineer                                                                                                                                                                          5
# Management Associate                                                                                                                                                                    5
# C++ Developer                                                                                                                                                                           5
# Systems Engineer                                                                                                                                                                        5
# Application Support Engineer                                                                                                                                                            5
# Chemist                                                                                                                                                                                 5
# Ansible Engineer                                                                                                                                                                        5
# IT Support Engineer                                                                                                                                                                     5
# Mechanical Design Engineer                                                                                                                                                              5
# HR Business Partner                                                                                                                                                                     5
# Senior Solutions Architect                                                                                                                                                              5
# Senior System Analyst                                                                                                                                                                   5
# Lead Product Manager                                                                                                                                                                    5
# Robotics Software Engineer                                                                                                                                                              5
# Senior Operation Manager                                                                                                                                                                5
# Market Specialist, GO Markets, India                                                                                                                                                    5
# Office Administrator                                                                                                                                                                    5
# Data Settlement Executive                                                                                                                                                               5
# Test Automation Engineer                                                                                                                                                                5
# Senior Business Analyst                                                                                                                                                                 5
# Accounts Associate                                                                                                                                                                      5
# Data Procurement Executive                                                                                                                                                              5
# Accounts Assistant (Accounting Firm)                                                                                                                                                    5
# Infrastructure Engineer                                                                                                                                                                 5
# Senior Account Manager                                                                                                                                                                  5
# Product Owner                                                                                                                                                                           5
# Fullstack Developer                                                                                                                                                                     5
# Logistics Assistant                                                                                                                                                                     5
# Associate Consultant                                                                                                                                                                    5
# Cloud Architect                                                                                                                                                                         5
# Account Executive                                                                                                                                                                       5
# Senior Software Engineer                                                                                                                                                                5
# Key Account Manager                                                                                                                                                                     5
# Admin Clerk                                                                                                                                                                             5
# Clinic Assistant                                                                                                                                                                        5
# Administrative Accounts Executive                                                                                                                                                       5
# Frontend Developer                                                                                                                                                                      5
# Algorithm Engineer                                                                                                                                                                      5
# Data Analyst                                                                                                                                                                            5
# SAS Developer                                                                                                                                                                           5
# Operations Technician                                                                                                                                                                   5
# Sales & Marketing Executive                                                                                                                                                             5
# IT Security Engineer                                                                                                                                                                    5
# Sales Executive                                                                                                                                                                         5
# SOFTWARE ENGINEER                                                                                                                                                                       5
# Quality Engineer                                                                                                                                                                        5
# Security Engineer                                                                                                                                                                       5
# Design Engineer                                                                                                                                                                         5
# ACCOUNT ASSISTANT                                                                                                                                                                       5
# Marketing Manager (B2B Marketing/ Traditional/ Digital/ HR Software)/ Paya Lebar - 7914                                                                                                 5
# Finance Assistant                                                                                                                                                                       5
# Software Engineering Manager                                                                                                                                                            5
# Laboratory Technician                                                                                                                                                                   5
# Software Developer #SGUnitedJobs                                                                                                                                                        4
# #SGUnitedJobs Scientist (Cybersecurity), I2R                                                                                                                                            4
# Accounts Executive                                                                                                                                                                      4
# Senior System Engineer                                                                                                                                                                  4
# Research Manager                                                                                                                                                                        4
# Social Media Manager                                                                                                                                                                    4
# #SGUnitedJobs Scientist – Quantum Technologies for Engineering (QTE), IMRE                                                                                                              4
# SAP Consultant                                                                                                                                                                          4
# Accounts cum Admin Assistant                                                                                                                                                            4
# Senior Systems Engineer                                                                                                                                                                 4
# Talent Acquisition Partner                                                                                                                                                              4
# Operations Engineer                                                                                                                                                                     4
# .Net Developer                                                                                                                                                                          4
# Application Developer                                                                                                                                                                   4
# Sales and Marketing Manager                                                                                                                                                             4
# Program Manager                                                                                                                                                                         4
# Administrative Accounts Assistant                                                                                                                                                       4
# Senior Procurement Executive                                                                                                                                                            4
# Payroll Executive                                                                                                                                                                       4
# E-Commerce Manager                                                                                                                                                                      4
# HR Manager                                                                                                                                                                              4
# Digital Marketing Specialist                                                                                                                                                            4
# Production Planner                                                                                                                                                                      4
# Recruiter                                                                                                                                                                               4
# Branch Manager                                                                                                                                                                          4
# Sales Operations Analyst                                                                                                                                                                4
# BIM Manager                                                                                                                                                                             4
# IT Engineer                                                                                                                                                                             4
# Facilities Engineer                                                                                                                                                                     4
# Full Stack Software Engineer                                                                                                                                                            4
# Senior Account Executive                                                                                                                                                                4
# Chief Technology Officer                                                                                                                                                                4
# Senior Software Engineer - Web                                                                                                                                                          4
# Senior Piping Engineer                                                                                                                                                                  4
# ACCOUNT EXECUTIVE                                                                                                                                                                       4
# Head of Marketing                                                                                                                                                                       4
# HR & Admin Executive                                                                                                                                                                    4
# Factory Manager (Woodlands) - 7914                                                                                                                                                      4
# Graphic Designer                                                                                                                                                                        4
# Senior Research Executive                                                                                                                                                               4
# Executive Assistant                                                                                                                                                                     4
# UI/UX Designer                                                                                                                                                                          4
# Software Developer                                                                                                                                                                      4
# Senior Application Consultant                                                                                                                                                           4
# SALES EXECUTIVE                                                                                                                                                                         4
# Talent Acquisition Specialist                                                                                                                                                           4
# Automation Tester                                                                                                                                                                       4
# Contract Purchaser (5 days, Yishun, $3000-3600)                                                                                                                                         4
# Financial Consultant                                                                                                                                                                    4
# ...
# Fieldwork Interviewer                                                                                                                                                                   1
# Sourcer                                                                                                                                                                                 1
# System Engineer #SGUnitedTraineeships                                                                                                                                                   1
# Senior HR Specialist (6 months contract, East)                                                                                                                                          1
# Performance Tester                                                                                                                                                                      1
# Project Engineer (FPSO)                                                                                                                                                                 1
# Director, Product Software Engineering                                                                                                                                                  1
# Business Management, ALMT APAC - Associate                                                                                                                                              1
# Team Lead (Java)  ($6000) Central area                                                                                                                                                  1
# Customer Service Assistant                                                                                                                                                              1
# Business System Analyst (Integration & Automation)                                                                                                                                      1
# Fab10A Facilities Tool Install Technologist                                                                                                                                             1
# Account & Admin Assistant #SGUnitedtraineeships #SGUP                                                                                                                                   1
# Security Consultant                                                                                                                                                                     1
# Senior Manager, Financial Services Tax                                                                                                                                                  1
# Head, Product                                                                                                                                                                           1
# Enterprise architect for Credit applications domain                                                                                                                                     1
# Sales Admin Officer ( Urgent)                                                                                                                                                           1
# Accounts Executive/Assistant                                                                                                                                                            1
# Senior QA Test Engineer                                                                                                                                                                 1
# FOOD & BEVERAGE OUTLET SUPERVISOR                                                                                                                                                       1
# Principal Database Engineer/IT Architect (Platforms & Middleware)                                                                                                                       1
# Customer Service Officer - 5.5 days needed at Tampines                                                                                                                                  1
# Salesforce Health Cloud Consultant                                                                                                                                                      1
# #SGUnitedJobs Content Marketing Specialist (Senior) - Asia & Global                                                                                                                     1
# Assistant Manager, Subsidies & Sector Grants Process Design #SgUnitedJobs                                                                                                               1
# Temp Application Verifier                                                                                                                                                               1
# Lead, Talent Strategic Projects                                                                                                                                                         1
# System Support officer (Jurong West)                                                                                                                                                    1
# Protocol Firmware Engineer                                                                                                                                                              1
# Project Manager, Financial Project                                                                                                                                                      1
# Interior Designer                                                                                                                                                                       1
# Marine Crew Executive/Crew Coordinator                                                                                                                                                  1
# Senior Manufacturing Technician                                                                                                                                                         1
# IT Executive (ref:120)                                                                                                                                                                  1
# Executive / Senior Executive (Technical)                                                                                                                                                1
# E-Commerce Executive/Manager                                                                                                                                                            1
# Product Manager (Compliance Analyst) - Up to $4K                                                                                                                                        1
# 1723-Technical Services/Support Consultant[ Software Application development/ implementation and support]                                                                               1
# Manager/Sr. Manager, Algorithm                                                                                                                                                          1
# Project Manager ( Public Security and Identity)                                                                                                                                         1
# Construction Electrical Engineer                                                                                                                                                        1
# Enterprise Solution Engineer, IT - Digital Affinity                                                                                                                                     1
# School Secretary / Receptionist                                                                                                                                                         1
# IT Manager (106)                                                                                                                                                                        1
# Product Manager, Machine Learning                                                                                                                                                       1
# HR Assistant 【Gul Road / 5 days 】5111                                                                                                                                                   1
# Platform Consultant                                                                                                                                                                     1
# ACCOUNT MANAGER #sgunitedtraineeships #sgup                                                                                                                                             1
# Condominium Manager                                                                                                                                                                     1
# Software Engineer (1079)                                                                                                                                                                1
# Clienteling & Loyalty Manager, SEA                                                                                                                                                      1
# Data Scientist (Global Fortune 500 Company)                                                                                                                                             1
# Assistant Manager, Group Product Development and Management                                                                                                                             1
# Principal Threat Researcher                                                                                                                                                             1
# IT Security Analyst / Senior Analyst                                                                                                                                                    1
# SOC Engineer 007                                                                                                                                                                        1
# Senior Business Analyst, AML                                                                                                                                                            1
# Manufacturing Technicians                                                                                                                                                               1
# Engineering Director, APAC                                                                                                                                                              1
# ASSISTANT MANAGER, TEST & SOFTWARE                                                                                                                                                      1
# Import Ocean Freight Officer [Toh Guan / Customer Service / Freight Forward / Sea Freight] 7094                                                                                         1
# Section Manager, Process Analytics                                                                                                                                                      1
# Event Operations Associate                                                                                                                                                              1
# Senior / Specialist, Human Resource                                                                                                                                                     1
# Senior Accountant                                                                                                                                                                       1
# Senior Project Manager - CardsPal                                                                                                                                                       1
# Research Engineer (Speech Recognition)                                                                                                                                                  1
# Compliance Conduct and Operational Risk - Securities Services Compliance - Vice President                                                                                               1
# SAP Personnel Development Functional Consultant                                                                                                                                         1
# Business Analyst, SAP HCM                                                                                                                                                               1
# Head of Cyber Security/Security Operations Centre (SOC)-IK                                                                                                                              1
# Finance Executive (Billing) - Asia up to $6000 (US MNC)                                                                                                                                 1
# Warehouse Assistant - Contract / East / Immediate                                                                                                                                       1
# Product Owner, Data - Digital Bank                                                                                                                                                      1
# Grant Writer                                                                                                                                                                            1
# ACCOUNT ASSISTANTS #SGUnitedJobs                                                                                                                                                        1
# Quality Assurance & Operation Executive [Boon Lay / ISO / Quality Management / QA] 7094                                                                                                 1
# Senior Manager - Consulting, Insurance                                                                                                                                                  1
# Process Control Engineer                                                                                                                                                                1
# Customer Support Executive/ Senior Executive, DDoS Mitigation Service (DMS)                                                                                                             1
# Vice President, Sales and Marketing                                                                                                                                                     1
# Business Analyst ( Financial Market Data Quality)                                                                                                                                       1
# Dimension Controller Engineer                                                                                                                                                           1
# Senior Tableau Developer                                                                                                                                                                1
# Name: job_title, dtype: int64

# %%
# using cvec to find out top occurring words in job title

# selecting only the job title
df_job_title = df['job_title']

# Instantiate a CountVectorizer with the chosen hyperparameters.
cvec = CountVectorizer(stop_words=('english', 'sgunitedtraineeships', 
                                   'up', 'admin', 'head', 'contract', 
                                   'senior', 'manager', 'customer', 
                                   'executive', 'vice', 'president', 'sgunitedjobs', 
                                   'assistant', '12', 'months', 'technology', 'and', 
                                   'days', 'associate', 'sgup', 'marketing', 'supply', 'sales', 
                                   'consumer'), 
                       ngram_range = (2, 2))

# fitting the CountVectorizer
cvec.fit(df_job_title)
df_job_title = cvec.transform(df_job_title)

# df of top occurring words
df_job_title_topwords = pd.DataFrame(df_job_title.toarray(), columns=cvec.get_feature_names())
df_job_title_topwords = get_top_words(df_job_title_topwords, 30)
df_job_title_topwords
# Out:
#                     words  counts
# 0        business analyst     575
# 1       software engineer     542
# 2    business development     166
# 3       research engineer     162
# 4            data analyst     158
# 5              full stack     158
# 6          data scientist     151
# 7           data engineer     145
# 8      software developer     131
# 9         devops engineer     129
# 10        research fellow     125
# 11         data analytics     118
# 12               big data     106
# 13       support engineer     104
# 14         java developer     100
# 15       network engineer      86
# 16     solution architect      83
# 17        system engineer      78
# 18        stack developer      75
# 19       project engineer      68
# 20    application support      64
# 21             data entry      62
# 22       machine learning      61
# 23            it business      61
# 24          test engineer      58
# 25       process engineer      57
# 26         human resource      57
# 27         system analyst      56
# 28     financial services      52
# 29  application developer      50

# %%
# custom function for standardizing job title
def job_title_standardizer(job_title):
    
    if 'data analyst' in job_title.lower():
        return 'data analyst'
    elif 'data analytics' in job_title.lower():
        return 'data analyst'
    elif 'analytics' in job_title.lower():
        return 'data analyst'
    elif 'visualization' in job_title.lower():
        return 'data analyst'
    
    elif 'data scientist' in job_title.lower():
        return 'data scientist'
    elif 'machine learning' in job_title.lower():
        return 'data scientist'
    elif 'science' in job_title.lower():
        return 'data scientist'
    elif 'modeler' in job_title.lower():
        return 'data scientist'
    
    elif 'business analyst' in job_title.lower():
        return 'business analyst'
    
    elif 'software engineer' in job_title.lower():
        return 'software engineer'
    elif 'front end' in job_title.lower():
        return 'software engineer'
    elif 'devops' in job_title.lower():
        return 'software engineer'    
    elif 'full stack' in job_title.lower():
        return 'software engineer'
    
    elif 'big data' in job_title.lower():
        return 'data engineer'
    elif 'data engineer' in job_title.lower():
        return 'data engineer'
    elif 'data integration' in job_title.lower():
        return 'data engineer' 
    elif 'data migration' in job_title.lower():
        return 'data engineer' 
    
    elif 'system engineer' in job_title.lower():
        return 'system engineer'
    elif 'solution architect' in job_title.lower():
        return 'system engineer'
    elif 'network engineer' in job_title.lower():
        return 'system engineer'
    elif 'solutions architect' in job_title.lower():
        return 'system engineer'
    elif 'architect' in job_title.lower():
        return 'system engineer'
    
    elif 'application' in job_title.lower():
        return 'software developer'
    elif 'java' in job_title.lower():
        return 'software developer'

    elif 'data governance' in job_title.lower():
        return 'data quality management'
    elif 'data strategy' in job_title.lower():
        return 'data quality management'   
    elif 'strategist' in job_title.lower():
        return 'data quality management'  
    elif 'data quality' in job_title.lower():
        return 'data quality management' 
    elif 'data solutions' in job_title.lower():
        return 'data quality management' 
    elif 'data solution' in job_title.lower():
        return 'data quality management' 
    elif 'data management' in job_title.lower():
        return 'data quality management' 
    elif 'data product manager' in job_title.lower():
        return 'data quality management' 
    elif 'security' in job_title.lower():
        return 'data quality management' 
    elif 'data maintenance' in job_title.lower():
        return 'data quality management' 
    elif 'protection' in job_title.lower():
        return 'data quality management'
    elif 'acquisition' in job_title.lower():
        return 'data quality management'
    
    elif 'research' in job_title.lower():
        return 'research scientist' 
    
    else:
        return 'others'

# %%
# applying custom function to column
df['job_title_standardized'] = df['job_title'].apply(job_title_standardizer)

# dropping indexes with 'others'
df = df[df['job_title_standardized'] != 'others']
df['job_title_standardized'].value_counts()
# Out:
# software engineer          869
# business analyst           554
# research scientist         534
# system engineer            450
# software developer         416
# data analyst               398
# data quality management    374
# data scientist             279
# data engineer              205
# Name: job_title_standardized, dtype: int64

# %% [markdown]
# ## Standardizing `employment_types` <a class="anchor" id="standardizeemploymenttype"></a>
# ---
# [Back to top!](#toc)

# %%
df.employment_types.value_counts()
# Out:
# Full Time                                                   1126
# Permanent; Full Time                                         892
# Permanent                                                    651
# Contract; Full Time                                          624
# Contract                                                     604
# Internship/Traineeship                                        63
# Contract; Permanent; Full Time                                48
# Contract; Permanent                                           33
# Part Time; Permanent                                           6
# Temporary                                                      4
# Permanent; Full Time; Internship/Traineeship                   4
# Part Time                                                      3
# Contract; Freelance; Permanent; Full Time                      3
# Full Time; Internship/Traineeship                              3
# Contract; Part Time                                            2
# Contract; Part Time; Full Time                                 1
# Part Time; Full Time; Internship/Traineeship                   1
# Contract; Flexi-work                                           1
# Contract; Permanent; Full Time; Internship/Traineeship         1
# Part Time; Freelance; Permanent; Full Time                     1
# Full Time; Flexi-work                                          1
# Contract; Permanent; Full Time; Flexi-work                     1
# Temporary; Full Time                                           1
# Flexi-work                                                     1
# Permanent; Full Time; Flexi-work; Internship/Traineeship       1
# Temporary; Contract                                            1
# Contract; Freelance; Permanent; Full Time; Flexi-work          1
# Part Time; Full Time                                           1
# Name: employment_types, dtype: int64

# %%
# finding the unique employment types
employment_types_list = df['employment_types'].tolist()

employment_types_list_split = []

for x in employment_types_list:
    x = x.split('; ')
    employment_types_list_split.extend(x)

employment_types = []
[employment_types.append(x) for x in employment_types_list_split if x not in employment_types]

employment_types
# Out:
# ['Permanent',
#  'Contract',
#  'Full Time',
#  'Internship/Traineeship',
#  'Part Time',
#  'Temporary',
#  'Flexi-work',
#  'Freelance']

# %%
# custom function for standardizing employment types
def employment_type_standardizer(employment_types):
    if 'permanent' in employment_types.lower():
        return 'permanent'
    elif 'contract' in employment_types.lower():
        return 'contract'
    elif 'full time' in employment_types.lower():
        return 'fulltime'
    elif 'part time' in employment_types.lower():
        return 'parttime'
    elif 'temporary' in employment_types.lower():
        return 'temporary'
    elif 'internship' in employment_types.lower():
        return 'internship'
    elif 'flexi-work' in employment_types.lower():
        return 'flexi-work'
    elif 'freelance' in employment_types.lower():
        return 'freelance'
    else:
        return 'others'

# %%
# applying custom function to column
df['employment_type_standardized'] = df['employment_types'].apply(employment_type_standardizer)
df['employment_type_standardized'].value_counts()
# Out:
# permanent     1642
# contract      1233
# fulltime      1133
# internship      63
# temporary        4
# parttime         3
# flexi-work       1
# Name: employment_type_standardized, dtype: int64

# %%
# dropping column
df.drop(columns=['employment_types'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4079 entries, 0 to 2668
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   job_title                     4079 non-null   object
#  1   job_description               4079 non-null   object
#  2   minimum_years_experience      4079 non-null   int64
#  3   categories                    4079 non-null   object
#  4   position_levels               4076 non-null   object
#  5   new_posting_date              4079 non-null   object
#  6   original_posting_date         4079 non-null   object
#  7   closing_date                  4079 non-null   object
#  8   last_updated                  4079 non-null   object
#  9   skills                        4079 non-null   object
#  10  organisation                  4079 non-null   object
#  11  salary_average                4079 non-null   float64
#  12  job_title_standardized        4079 non-null   object
#  13  employment_type_standardized  4079 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 478.0+ KB

# %% [markdown]
# ## Standardizing `position_levels` <a class="anchor" id="standardizepositionlevel"></a>
# ---
# [Back to top!](#toc)

# %%
df.position_levels.value_counts()
# Out:
# Professional                            1326
# Executive                                945
# Senior Executive                         708
# Manager                                  313
# Junior Executive                         249
# Fresh/entry level                        195
# Middle Management                        145
# Senior Management                        102
# Non-executive                             92
# Senior Management; Middle Management       1
# Name: position_levels, dtype: int64

# %%
# custom function for standardizing position levels
def position_levels_standardizer(position_levels):
    if 'Senior Executive' in position_levels:
        return 'senior executive'
    elif 'Junior Executive' in position_levels:
        return 'junior executive'
    elif 'Non-executive' in position_levels:
        return 'non-executive'
    elif 'Executive' in position_levels:
        return 'executive'
    elif 'Middle Management' in position_levels:
        return 'middle management'
    elif 'Senior Management' in position_levels:
        return 'senior management'
    elif 'Professional' in position_levels:
        return 'professional'
    elif 'Manager' in position_levels:
        return 'manager'
    elif 'entry level' in position_levels:
        return 'entry level'
    else:
        return 'others'

# %%
# ensuring dtype is str
df['position_levels'] = df['position_levels'].astype('str', copy=True)

# applying custom function to column
df['position_level_standardized'] = df['position_levels'].apply(position_levels_standardizer)

# dropping indexes with 'others'
df = df[df['position_level_standardized'] != 'others']
df['position_level_standardized'].value_counts()
# Out:
# professional         1326
# executive             945
# senior executive      708
# manager               313
# junior executive      249
# entry level           195
# middle management     146
# senior management     102
# non-executive          92
# Name: position_level_standardized, dtype: int64

# %%
# dropping column
df.drop(columns=['position_levels'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4076 entries, 0 to 2668
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   job_title                     4076 non-null   object
#  1   job_description               4076 non-null   object
#  2   minimum_years_experience      4076 non-null   int64
#  3   categories                    4076 non-null   object
#  4   new_posting_date              4076 non-null   object
#  5   original_posting_date         4076 non-null   object
#  6   closing_date                  4076 non-null   object
#  7   last_updated                  4076 non-null   object
#  8   skills                        4076 non-null   object
#  9   organisation                  4076 non-null   object
#  10  salary_average                4076 non-null   float64
#  11  job_title_standardized        4076 non-null   object
#  12  employment_type_standardized  4076 non-null   object
#  13  position_level_standardized   4076 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 477.7+ KB

# %% [markdown]
# ## Converting datetime variables <a class="anchor" id="convertdatetime"></a>
# ---
# [Back to top!](#toc)

# %%
df.head()
# Out:
#                                            job_title  \
# 0         Senior Derivatives XA Market Data Engineer
# 1  IT - Business Analyst (Data Analytics and Mach...
# 2  Junior Data Analyst (Finance / Python) - up to...
# 3                          Data Analytics Consultant
# 4                         (IT)- Data science analyst
#
#                                      job_description  \
# 0  At ICE we approach every challenge as an oppor...
# 1  [ COLLECTION, USE AND DISCLOSURE OF PERSONAL D...
# 2  We are a top 8 global IT services company with...
# 3  This TMCA* (TeSA Mid-Career Advancement) progr...
# 4  We are a top 8 global IT services company with...
#
#    minimum_years_experience  \
# 0                         5
# 1                         3
# 2                         2
# 3                        15
# 4                         2
#
#                                           categories new_posting_date  \
# 0        Banking and Finance; Information Technology       2021-04-28
# 1                             Information Technology       2021-04-23
# 2                             Information Technology       2021-04-14
# 3  Consulting; Education and Training; Informatio...       2021-04-30
# 4                             Information Technology       2021-04-18
#
#   original_posting_date closing_date              last_updated  \
# 0            2021-03-17   2021-05-28  2021-05-10T16:39:19.000Z
# 1            2021-04-23   2021-05-23  2021-05-10T16:28:53.000Z
# 2            2021-04-14   2021-05-14  2021-05-10T16:34:46.000Z
# 3            2020-12-18   2021-05-30  2021-05-10T16:41:51.000Z
# 4            2021-04-18   2021-05-18  2021-05-10T16:28:23.000Z
#
#                                               skills  \
# 0  Analytics; Communication; Data; Detail Oriente...
# 1  Agile; Agile Methodolgy; Banking; Business Ana...
# 2  Access; Business Process; Data; Data Analysis;...
# 3  Analysis; Business Change Management; Business...
# 4  Business Process; Data; MySQL; MySQL DBA; Orac...
#
#                             organisation  salary_average  \
# 0  ICE DATA SERVICES SINGAPORE PTE. LTD.         13125.0
# 1           NTT DATA SINGAPORE PTE. LTD.          4500.0
# 2           NTT DATA SINGAPORE PTE. LTD.          3400.0
# 3    DATA & ANALYTICS CAPITALS PTE. LTD.          6000.0
# 4           NTT DATA SINGAPORE PTE. LTD.          6000.0
#
#   job_title_standardized employment_type_standardized  \
# 0          data engineer                    permanent
# 1           data analyst                     contract
# 2           data analyst                     contract
# 3           data analyst                     fulltime
# 4         data scientist                     contract
#
#   position_level_standardized
# 0                professional
# 1                   executive
# 2            junior executive
# 3                professional
# 4            senior executive

# %%
# converting to datetime format
df['new_posting_date'] = pd.to_datetime(df['new_posting_date'], format="%Y-%m-%d")
df['original_posting_date'] = pd.to_datetime(df['original_posting_date'], format="%Y-%m-%d")
df['closing_date'] = pd.to_datetime(df['closing_date'], format="%Y-%m-%d")

# getting no. of days from posting date
df['days_new_posting_closing'] = df['closing_date'] - df['new_posting_date']
df['days_new_posting_closing'] = df['days_new_posting_closing']/np.timedelta64(1,"D")

# getting no. of days from original posting date
df['days_original_posting_closing'] = df['closing_date'] - df['original_posting_date']
df['days_original_posting_closing'] = df['days_original_posting_closing']/np.timedelta64(1,"D")

# dropping columns
df.drop(columns=['new_posting_date', 'original_posting_date', 'closing_date', 'last_updated'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4076 entries, 0 to 2668
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   job_title                      4076 non-null   object
#  1   job_description                4076 non-null   object
#  2   minimum_years_experience       4076 non-null   int64
#  3   categories                     4076 non-null   object
#  4   skills                         4076 non-null   object
#  5   organisation                   4076 non-null   object
#  6   salary_average                 4076 non-null   float64
#  7   job_title_standardized         4076 non-null   object
#  8   employment_type_standardized   4076 non-null   object
#  9   position_level_standardized    4076 non-null   object
#  10  days_new_posting_closing       4076 non-null   float64
#  11  days_original_posting_closing  4076 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 414.0+ KB

# %% [markdown]
# ## Exporting Dataset for EDA <a class="anchor" id="exportcsv"></a>
# ---
# [Back to top!](#toc)

# %%
df.to_csv('../data/cleaned_dataset.csv', index=False)
